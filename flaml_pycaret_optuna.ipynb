# %% [markdown]
# In this notebook I attempt to produce reasonable forecasts for the cleaned datasets.
#
# Firstly, I apply a couple of lazy classifer-like packages (Pycaret, skforecast, lazyclassifier) on the dataset. This will enable me to build a lot of basic models without much code and help to quickly understand which models work better without any parameter tuning.
#
# Then after getting the models arranged with respect to their accuracies, I will then choose the top models and apply hyperparameter tuning (optuna/hyperopt).
#
# I will also explore the possibilities of building an assemblage model by applying appropriate bagging techniques with a further aim to reduce model over-fitting.

# %% [markdown]
# ## PyCaret is an open-source, low-code machine learning library in Python that automates machine learning workflows.

# %%
# Importing some of the required packages
from pycaret.time_series import *
import pandas as pd
import numpy as np

# %%
# Loading the cleaned dataset. Cleaning was done in a previous notebook
dx = pd.read_csv(r'/home/nkem/Documents/PhD_Research/allN11Oct2022.csv')
dx.head()
# Out:
#   incidentdate  year  month  day company contaminant spillareahabitat cause  \
# 0   2005-01-05  2005      1    5     MPN          cr               of   ome
# 1   2005-01-08  2005      1    8     MPN          cr               of   eqf
# 2   2005-01-31  2005      1   31    NAOC          cr               la   cor
# 3   2005-02-08  2005      2    8     MPN          cr               of   eqf
# 4   2005-03-08  2005      3    8     MPN          cr               of   eqf
#
#    estimatedqty
# 0        0.0568
# 1        0.0002
# 2      100.0000
# 3        0.0300
# 4        3.0000

# %%
# Changing the incidentdate column to pandas datetime
dx['incidentdate'] = pd.to_datetime(dx['incidentdate'])
td = dx.copy()

# Downsampling from daily timeframe to the monthly timeframe
dk = td.groupby([pd.Grouper(key='incidentdate', freq='M')])['estimatedqty'].agg(['sum','size'])
dk = dk.reset_index()

# Renaming the columns
dk.rename(columns={"sum":"estimatedqty", "size":"spillno"}, inplace=True)

# Filtering out the estimatedqty column and dropping the last incomplete entry
df = dk[["incidentdate","spillno"]]
df = df.set_index("incidentdate")
df = df.drop(index="2022-10-31")

# Feauture enginneering - creating month and year column from the incidentdate column
df= df.reset_index()
df["month"] = df["incidentdate"].dt.month
df["year"] = df["incidentdate"].dt.year
dt = df[["incidentdate","spillno","month", "year"]]
dt = dt.set_index("incidentdate")
dt.tail()
# Out:
#               spillno  month  year
# incidentdate
# 2022-05-31         22      5  2022
# 2022-06-30         48      6  2022
# 2022-07-31         20      7  2022
# 2022-08-31         60      8  2022
# 2022-09-30         38      9  2022

# %%
data = dt.copy()
# data split into train & test sets
end_train = '2022-03-31'
start_test = '2022-04-30'
end_test = '2022-06-30'

data_train = dt.loc[: end_train, :]
data_test  = dt.loc[start_test: end_test]

print(f"Train dates      : {data_train.index.min()} --- {data_train.index.max()}")
print(f"Test dates       : {data_test.index.min()} --- {data_test.index.max()}")
# Out:
# Train dates      : 2005-01-31 00:00:00 --- 2022-03-31 00:00:00
# Test dates       : 2022-04-30 00:00:00 --- 2022-06-30 00:00:00

# %%
# Select exogenous variables, including those generated by one hot encoding.
exog_variables = [column for column in dt.columns
                      if column.startswith(('year', 'month'))]
#exog_variables.extend(['estimatedqty'])
#print(exog_variables)

# %%
# For datasets with exogenous variables, a Pycaret experiment demands we explicitly specify the target variable. The Pycaret package helps to divide datasets into training and test datasets so there will not be need for the division above.

target = "spillno"
exog_vars = ['year', 'month']
include = [target] + exog_vars
data = data[include]
data.tail()
# Out:
#               spillno  year  month
# incidentdate
# 2022-05-31         22  2022      5
# 2022-06-30         48  2022      6
# 2022-07-31         20  2022      7
# 2022-08-31         60  2022      8
# 2022-09-30         38  2022      9

# %%
# Forecasting horizon is 3 months
FH= 3
metric = "rmse"

# %%
# Global figure settings for notebook
fig_kwargs = {"renderer": "notebook", "width": 1000, "height": 600}

# %%
# Pycaret experiment design
 
exp_auto = TSForecastingExperiment()

# enforce_exogenous=False --> Use multivariate forecasting when model supports it, else use univariate forecasting
exp_auto.setup(data=data, target=target, fh=FH, enforce_exogenous=False,fig_kwargs=fig_kwargs, session_id=24,use_gpu=False)
# Out:
# <style type="text/css">
# #T_e324f_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e324f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e324f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e324f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e324f_row0_col1" class="data row0 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e324f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e324f_row1_col1" class="data row1 col1" >spillno</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e324f_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_e324f_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e324f_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_e324f_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e324f_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_e324f_row4_col1" class="data row4 col1" >(213, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e324f_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_e324f_row5_col1" class="data row5 col1" >(213, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e324f_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_e324f_row6_col1" class="data row6 col1" >(210, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e324f_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_e324f_row7_col1" class="data row7 col1" >(3, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e324f_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_e324f_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e324f_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_e324f_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e324f_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_e324f_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e324f_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_e324f_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e324f_row12_col0" class="data row12 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_e324f_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e324f_row13_col0" class="data row13 col0" >Seasonality Present</td>
#       <td id="T_e324f_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e324f_row14_col0" class="data row14 col0" >Seasonalities Detected</td>
#       <td id="T_e324f_row14_col1" class="data row14 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e324f_row15_col0" class="data row15 col0" >Primary Seasonality</td>
#       <td id="T_e324f_row15_col1" class="data row15 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e324f_row16_col0" class="data row16 col0" >Target Strictly Positive</td>
#       <td id="T_e324f_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e324f_row17_col0" class="data row17 col0" >Target White Noise</td>
#       <td id="T_e324f_row17_col1" class="data row17 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e324f_row18_col0" class="data row18 col0" >Recommended d</td>
#       <td id="T_e324f_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e324f_row19_col0" class="data row19 col0" >Recommended Seasonal D</td>
#       <td id="T_e324f_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e324f_row20_col0" class="data row20 col0" >Preprocess</td>
#       <td id="T_e324f_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e324f_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_e324f_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e324f_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_e324f_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e324f_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_e324f_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e324f_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_e324f_row24_col1" class="data row24 col1" >ts-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e324f_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e324f_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_e324f_row25_col1" class="data row25 col1" >e248</td>
#     </tr>
#   </tbody>
# </table>

# %%
# List of available models
exp_auto.models()
# Out:
#                                                               Name  \
# ID
# naive                                             Naive Forecaster
# grand_means                                 Grand Means Forecaster
# snaive                                   Seasonal Naive Forecaster
# polytrend                              Polynomial Trend Forecaster
# arima                                                        ARIMA
# auto_arima                                              Auto ARIMA
# exp_smooth                                   Exponential Smoothing
# croston                                                    Croston
# ets                                                            ETS
# theta                                             Theta Forecaster
# tbats                                                        TBATS
# bats                                                          BATS
# prophet                                                    Prophet
# lr_cds_dt               Linear w/ Cond. Deseasonalize & Detrending
# en_cds_dt          Elastic Net w/ Cond. Deseasonalize & Detrending
# ridge_cds_dt             Ridge w/ Cond. Deseasonalize & Detrending
# lasso_cds_dt             Lasso w/ Cond. Deseasonalize & Detrending
# lar_cds_dt       Least Angular Regressor w/ Cond. Deseasonalize...
# llar_cds_dt      Lasso Least Angular Regressor w/ Cond. Deseaso...
# br_cds_dt        Bayesian Ridge w/ Cond. Deseasonalize & Detren...
# huber_cds_dt             Huber w/ Cond. Deseasonalize & Detrending
# par_cds_dt       Passive Aggressive w/ Cond. Deseasonalize & De...
# omp_cds_dt       Orthogonal Matching Pursuit w/ Cond. Deseasona...
# knn_cds_dt         K Neighbors w/ Cond. Deseasonalize & Detrending
# dt_cds_dt        Decision Tree w/ Cond. Deseasonalize & Detrending
# rf_cds_dt        Random Forest w/ Cond. Deseasonalize & Detrending
# et_cds_dt          Extra Trees w/ Cond. Deseasonalize & Detrending
# gbr_cds_dt       Gradient Boosting w/ Cond. Deseasonalize & Det...
# ada_cds_dt            AdaBoost w/ Cond. Deseasonalize & Detrending
# xgboost_cds_dt   Extreme Gradient Boosting w/ Cond. Deseasonali...
# lightgbm_cds_dt  Light Gradient Boosting w/ Cond. Deseasonalize...
# catboost_cds_dt  CatBoost Regressor w/ Cond. Deseasonalize & De...
#
#                                                          Reference  Turbo
# ID
# naive                     sktime.forecasting.naive.NaiveForecaster   True
# grand_means               sktime.forecasting.naive.NaiveForecaster   True
# snaive                    sktime.forecasting.naive.NaiveForecaster   True
# polytrend        sktime.forecasting.trend.PolynomialTrendForeca...   True
# arima                               sktime.forecasting.arima.ARIMA   True
# auto_arima                      sktime.forecasting.arima.AutoARIMA   True
# exp_smooth       sktime.forecasting.exp_smoothing.ExponentialSm...   True
# croston                         sktime.forecasting.croston.Croston   True
# ets                                 sktime.forecasting.ets.AutoETS   True
# theta                     sktime.forecasting.theta.ThetaForecaster   True
# tbats                               sktime.forecasting.tbats.TBATS  False
# bats                                  sktime.forecasting.bats.BATS  False
# prophet          pycaret.containers.models.time_series.ProphetP...  False
# lr_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# en_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# ridge_cds_dt     pycaret.containers.models.time_series.BaseCdsD...   True
# lasso_cds_dt     pycaret.containers.models.time_series.BaseCdsD...   True
# lar_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# llar_cds_dt      pycaret.containers.models.time_series.BaseCdsD...   True
# br_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# huber_cds_dt     pycaret.containers.models.time_series.BaseCdsD...   True
# par_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# omp_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# knn_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# dt_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# rf_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# et_cds_dt        pycaret.containers.models.time_series.BaseCdsD...   True
# gbr_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# ada_cds_dt       pycaret.containers.models.time_series.BaseCdsD...   True
# xgboost_cds_dt   pycaret.containers.models.time_series.BaseCdsD...   True
# lightgbm_cds_dt  pycaret.containers.models.time_series.BaseCdsD...   True
# catboost_cds_dt  pycaret.containers.models.time_series.BaseCdsD...   True

# %%
# Model fiting for 5 mins time budget
# Turbo = False, will ensure that slower models like Prophet will be included
best = exp_auto.compare_models(sort=metric, turbo=False, budget_time=5)
# Out:
# <style type="text/css">
# #T_6bd5b_ th {
#   text-align: left;
# }
# #T_6bd5b_row0_col0, #T_6bd5b_row0_col1, #T_6bd5b_row0_col3, #T_6bd5b_row0_col5, #T_6bd5b_row0_col6, #T_6bd5b_row1_col0, #T_6bd5b_row1_col1, #T_6bd5b_row1_col2, #T_6bd5b_row1_col3, #T_6bd5b_row1_col4, #T_6bd5b_row1_col5, #T_6bd5b_row1_col6, #T_6bd5b_row1_col7, #T_6bd5b_row2_col0, #T_6bd5b_row2_col1, #T_6bd5b_row2_col2, #T_6bd5b_row2_col3, #T_6bd5b_row2_col4, #T_6bd5b_row2_col5, #T_6bd5b_row2_col6, #T_6bd5b_row2_col7, #T_6bd5b_row3_col0, #T_6bd5b_row3_col1, #T_6bd5b_row3_col2, #T_6bd5b_row3_col3, #T_6bd5b_row3_col4, #T_6bd5b_row3_col5, #T_6bd5b_row3_col6, #T_6bd5b_row3_col7, #T_6bd5b_row4_col0, #T_6bd5b_row4_col2, #T_6bd5b_row4_col4, #T_6bd5b_row4_col7, #T_6bd5b_row5_col0, #T_6bd5b_row5_col1, #T_6bd5b_row5_col2, #T_6bd5b_row5_col3, #T_6bd5b_row5_col4, #T_6bd5b_row5_col5, #T_6bd5b_row5_col6, #T_6bd5b_row5_col7, #T_6bd5b_row6_col0, #T_6bd5b_row6_col1, #T_6bd5b_row6_col2, #T_6bd5b_row6_col3, #T_6bd5b_row6_col4, #T_6bd5b_row6_col5, #T_6bd5b_row6_col6, #T_6bd5b_row6_col7, #T_6bd5b_row7_col0, #T_6bd5b_row7_col1, #T_6bd5b_row7_col2, #T_6bd5b_row7_col3, #T_6bd5b_row7_col4, #T_6bd5b_row7_col5, #T_6bd5b_row7_col6, #T_6bd5b_row7_col7, #T_6bd5b_row8_col0, #T_6bd5b_row8_col1, #T_6bd5b_row8_col2, #T_6bd5b_row8_col3, #T_6bd5b_row8_col4, #T_6bd5b_row8_col5, #T_6bd5b_row8_col6, #T_6bd5b_row8_col7, #T_6bd5b_row9_col0, #T_6bd5b_row9_col1, #T_6bd5b_row9_col2, #T_6bd5b_row9_col3, #T_6bd5b_row9_col4, #T_6bd5b_row9_col5, #T_6bd5b_row9_col6, #T_6bd5b_row9_col7, #T_6bd5b_row10_col0, #T_6bd5b_row10_col1, #T_6bd5b_row10_col2, #T_6bd5b_row10_col3, #T_6bd5b_row10_col4, #T_6bd5b_row10_col5, #T_6bd5b_row10_col6, #T_6bd5b_row10_col7, #T_6bd5b_row11_col0, #T_6bd5b_row11_col1, #T_6bd5b_row11_col2, #T_6bd5b_row11_col3, #T_6bd5b_row11_col4, #T_6bd5b_row11_col5, #T_6bd5b_row11_col6, #T_6bd5b_row11_col7, #T_6bd5b_row12_col0, #T_6bd5b_row12_col1, #T_6bd5b_row12_col2, #T_6bd5b_row12_col3, #T_6bd5b_row12_col4, #T_6bd5b_row12_col5, #T_6bd5b_row12_col6, #T_6bd5b_row12_col7, #T_6bd5b_row13_col0, #T_6bd5b_row13_col1, #T_6bd5b_row13_col2, #T_6bd5b_row13_col3, #T_6bd5b_row13_col4, #T_6bd5b_row13_col5, #T_6bd5b_row13_col6, #T_6bd5b_row13_col7, #T_6bd5b_row14_col0, #T_6bd5b_row14_col1, #T_6bd5b_row14
row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6bd5b_row0_col8, #T_6bd5b_row1_col8, #T_6bd5b_row2_col8, #T_6bd5b_row3_col8, #T_6bd5b_row4_col8, #T_6bd5b_row5_col8, #T_6bd5b_row6_col8, #T_6bd5b_row7_col8, #T_6bd5b_row8_col8, #T_6bd5b_row9_col8, #T_6bd5b_row10_col8, #T_6bd5b_row11_col8, #T_6bd5b_row12_col8, #T_6bd5b_row13_col8, #T_6bd5b_row14_col8, #T_6bd5b_row15_col8, #T_6bd5b_row16_col8, #T_6bd5b_row17_col8, #T_6bd5b_row18_col8, #T_6bd5b_row19_col8, #T_6bd5b_row20_col8, #T_6bd5b_row21_col8, #T_6bd5b_row22_col8, #T_6bd5b_row23_col8, #T_6bd5b_row24_col8, #T_6bd5b_row25_col8, #T_6bd5b_row26_col8, #T_6bd5b_row27_col8, #T_6bd5b_row28_col8, #T_6bd5b_row30_col8, #T_6bd5b_row31_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6bd5b_row29_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6bd5b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MASE</th>
#       <th class="col_heading level0 col2" >RMSSE</th>
#       <th class="col_heading level0 col3" >MAE</th>
#       <th class="col_heading level0 col4" >RMSE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#       <th class="col_heading level0 col6" >SMAPE</th>
#       <th class="col_heading level0 col7" >R2</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bd5b_level0_row0" class="row_heading level0 row0" >dt_cds_dt</th>
#       <td id="T_6bd5b_row0_col0" class="data row0 col0" >Decision Tree w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_6bd5b_row0_col1" class="data row0 col1" >0.2874</td>
#       <td id="T_6bd5b_row0_col2" class="data row0 col2" >0.2287</td>
#       <td id="T_6bd5b_row0_col3" class="data row0 col3" >6.0782</td>
#       <td id="T_6bd5b_row0_col4" class="data row0 col4" >6.6908</td>
#       <td id="T_6bd5b_row0_col5" class="data row0 col5" >0.2698</td>
#       <td id="T_6bd5b_row0_col6" class="data row0 col6" >0.2395</td>
#       <td id="T_6bd5b_row0_col7" class="data row0 col7" >0.1241</td>
#       <td id="T_6bd5b_row0_col8" class="data row0 col8" >0.0700</td>
#     </tr>
#     <tr>
#       <th id="T_6bd5b_level0_row1" class="row_heading level0 row1" >snaive</th>
#       <td id="T_6bd5b_row1_col0" class="data row1 col0" >Seasonal Naive Forecaster</td>
#       <td id="T_6bd5b_row1_col1" class="data row1 col1" >0.3149</td>
#       <td id="T_6bd5b_row1_col2" class="data row1 col2" >0.2555</td>
#       <td id="T_6bd5b_row1_col3" class="data row1 col3" >6.6667</td>
#       <td id="T
# Processing:   0%|          | 0/137 [00:00<?, ?it/s]

# %%
# Increased time budget = 60mins
# Pycaret experiment design
 
exp_auto = TSForecastingExperiment()

# enforce_exogenous=False --> Use multivariate forecasting when model supports it, else use univariate forecasting
exp_auto.setup(data=data, target=target, fh=FH, enforce_exogenous=False,fig_kwargs=fig_kwargs, session_id=25,use_gpu=False)
# Out:
# <style type="text/css">
# #T_669ec_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_669ec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_669ec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_669ec_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_669ec_row0_col1" class="data row0 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_669ec_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_669ec_row1_col1" class="data row1 col1" >spillno</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_669ec_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_669ec_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_669ec_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_669ec_row3_col1" class="data row3 col1" >Present</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_669ec_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_669ec_row4_col1" class="data row4 col1" >(213, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_669ec_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_669ec_row5_col1" class="data row5 col1" >(213, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_669ec_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_669ec_row6_col1" class="data row6 col1" >(210, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_669ec_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_669ec_row7_col1" class="data row7 col1" >(3, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_669ec_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_669ec_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_669ec_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_669ec_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_669ec_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_669ec_row10_col1" class="data row10 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_669ec_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_669ec_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_669ec_row12_col0" class="data row12 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_669ec_row12_col1" class="data row12 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_669ec_row13_col0" class="data row13 col0" >Seasonality Present</td>
#       <td id="T_669ec_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_669ec_row14_col0" class="data row14 col0" >Seasonalities Detected</td>
#       <td id="T_669ec_row14_col1" class="data row14 col1" >[12]</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_669ec_row15_col0" class="data row15 col0" >Primary Seasonality</td>
#       <td id="T_669ec_row15_col1" class="data row15 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_669ec_row16_col0" class="data row16 col0" >Target Strictly Positive</td>
#       <td id="T_669ec_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_669ec_row17_col0" class="data row17 col0" >Target White Noise</td>
#       <td id="T_669ec_row17_col1" class="data row17 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_669ec_row18_col0" class="data row18 col0" >Recommended d</td>
#       <td id="T_669ec_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_669ec_row19_col0" class="data row19 col0" >Recommended Seasonal D</td>
#       <td id="T_669ec_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_669ec_row20_col0" class="data row20 col0" >Preprocess</td>
#       <td id="T_669ec_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_669ec_row21_col0" class="data row21 col0" >CPU Jobs</td>
#       <td id="T_669ec_row21_col1" class="data row21 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_669ec_row22_col0" class="data row22 col0" >Use GPU</td>
#       <td id="T_669ec_row22_col1" class="data row22 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_669ec_row23_col0" class="data row23 col0" >Log Experiment</td>
#       <td id="T_669ec_row23_col1" class="data row23 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_669ec_row24_col0" class="data row24 col0" >Experiment Name</td>
#       <td id="T_669ec_row24_col1" class="data row24 col1" >ts-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_669ec_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_669ec_row25_col0" class="data row25 col0" >USI</td>
#       <td id="T_669ec_row25_col1" class="data row25 col1" >cfaf</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Increasing time budget to 60mins
# Turbo = False, will ensure that slower models like Prophet will be included
best = exp_auto.compare_models(sort=metric, turbo=False, budget_time=60)
# Out:
# <style type="text/css">
# #T_84af4_ th {
#   text-align: left;
# }
# #T_84af4_row0_col0, #T_84af4_row0_col1, #T_84af4_row0_col3, #T_84af4_row0_col5, #T_84af4_row0_col6, #T_84af4_row0_col7, #T_84af4_row1_col0, #T_84af4_row1_col1, #T_84af4_row1_col2, #T_84af4_row1_col3, #T_84af4_row1_col4, #T_84af4_row1_col5, #T_84af4_row1_col6, #T_84af4_row1_col7, #T_84af4_row2_col0, #T_84af4_row2_col1, #T_84af4_row2_col2, #T_84af4_row2_col3, #T_84af4_row2_col4, #T_84af4_row2_col5, #T_84af4_row2_col6, #T_84af4_row2_col7, #T_84af4_row3_col0, #T_84af4_row3_col1, #T_84af4_row3_col2, #T_84af4_row3_col3, #T_84af4_row3_col4, #T_84af4_row3_col5, #T_84af4_row3_col6, #T_84af4_row4_col0, #T_84af4_row4_col2, #T_84af4_row4_col4, #T_84af4_row4_col7, #T_84af4_row5_col0, #T_84af4_row5_col1, #T_84af4_row5_col2, #T_84af4_row5_col3, #T_84af4_row5_col4, #T_84af4_row5_col5, #T_84af4_row5_col6, #T_84af4_row5_col7, #T_84af4_row6_col0, #T_84af4_row6_col1, #T_84af4_row6_col2, #T_84af4_row6_col3, #T_84af4_row6_col4, #T_84af4_row6_col5, #T_84af4_row6_col6, #T_84af4_row6_col7, #T_84af4_row7_col0, #T_84af4_row7_col1, #T_84af4_row7_col2, #T_84af4_row7_col3, #T_84af4_row7_col4, #T_84af4_row7_col5, #T_84af4_row7_col6, #T_84af4_row7_col7, #T_84af4_row8_col0, #T_84af4_row8_col1, #T_84af4_row8_col2, #
_row22_col7, #T_84af4_row23_col0, #T_84af4_row23_col1, #T_84af4_row23_col2, #T_84af4_row23_col3, #T_84af4_row23_col4, #T_84af4_row23_col5, #T_84af4_row23_col6, #T_84af4_row23_col7, #T_84af4_row24_col0, #T_84af4_row24_col1, #T_84af4_row24_col2, #T_84af4_row24_col3, #T_84af4_row24_col4, #T_84af4_row24_col5, #T_84af4_row24_col6, #T_84af4_row24_col7, #T_84af4_row25_col0, ...
#   text-align: left;
# }
# #T_84af4_row0_col2, #T_84af4_row0_col4, #T_84af4_row3_col7, #T_84af4_row4_col1, #T_84af4_row4_col3, #T_84af4_row4_col5, #T_84af4_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_84af4_row0_col8, #T_84af4_row1_col8, #T_84af4_row2_col8, #T_84af4_row3_col8, #T_84af4_row4_col8, #T_84af4_row5_col8, #T_84af4_row6_col8, #T_84af4_row7_col8, #T_84af4_row8_col8, #T_84af4_row9_col8, #T_84af4_row10_col8, #T_84af4_row11_col8, #T_84af4_row12_col8, #T_84af4_row13_col8, #T_84af4_row14_col8, #T_84af4_row15_col8, #T_84af4_row16_col8, #T_84af4_row17_col8, #T_84af4_row18_col8, #T_84af4_row19_col8, #T_84af4_row20_col8, #T_84af4_row21_col8, #T_84af4_row22_col8, #T_84af4_row23_col8, #T_84af4_row24_col8, #T_84af4_row25_col8, #T_84af4_row26_col8, #T_84af4_row27_col8, #T_84af4_row28_col8, #T_84af4_row30_col8, #T_84af4_row31_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_84af4_row29_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_84af4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MASE</th>
#       <th class="col_heading level0 col2" >RMSSE</th>
#       <th class="col_heading level0 col3" >MAE</th>
#       <th class="col_heading level0 col4" >RMSE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#       <th class="col_heading level0 col6" >SMAPE</th>
#       <th class="col_heading level0 col7" >R2</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84af4_level0_row0" class="row_heading level0 row0" >dt_cds_dt</th>
#       <td id="T_84af4_row0_col0" class="data row0 col0" >Decision Tree w/ Cond. Deseasonalize & Detrending</td>
#       <td id="T_84af4_row0_col1" class="data row0 col1" >0.3088</td>
#       <td id="T_84af4_row0_col2" class="data row0 col2" >0.2395</td>
#       <td id="T_84af4_row0_col3" class="data row0 col3" >6.5376</td>
#       <td id="T_84af4_row0_col4" class="data row0 col4" >7.0081</td>
#       <td id="T_84af4_row0_col5" class="data row0 col5" >0.2824</td>
#       <td id="T_84af4_row0_col6" class="data row0 col6" >0.2510</td>
#       <td id="T_84af4_row0_col7" class="data row0 col7" >-0.0251</td>
#       <td id="T_84af4_row0_col8" class="data row0 col8" >0.0667</td>
#     </tr>
#     <tr>
#       <th id="T_84af4_level0_row1" class="row_heading level0 row1" >snaive</th>
#       <td id="T_84af4_row1_col0" class="data row1 col0" >Seasonal Naive Forecaster</td>
#       <td id="T_84af4_row1_col1" class="data row1 col1" >0.3149</td>
#       <td id="T_84af4_row1_col2" class="data row1 col2" >0.2555</td>
#       <td id="T_84af4_row1_col3" class="data row1 col3" >6.6667</td>
#       <td id="
# Processing:   0%|          | 0/137 [00:00<?, ?it/s]

# %% [markdown]
# Increasing the time budget in Pycaret didn't improve the accuracies of the models nor the runtime of the experiment
